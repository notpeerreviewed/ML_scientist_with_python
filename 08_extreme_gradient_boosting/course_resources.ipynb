# %%
import pandas as pd

ames_preprocessed = pd.read_csv("https://assets.datacamp.com/production/repositories/943/datasets/4dbcaee889ef06fb0763e4a8652a4c1f268359b2/ames_housing_trimmed_processed.csv")
ames_preprocessed.head()
# Out:
#    MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0          60         65.0     8450            7            5       2003
# 1          20         80.0     9600            6            8       1976
# 2          60         68.0    11250            7            5       2001
# 3          70         60.0     9550            7            5       1915
# 4          60         84.0    14260            8            5       2000
#
#    Remodeled  GrLivArea  BsmtFullBath  BsmtHalfBath  ...  HouseStyle_1.5Unf  \
# 0          0       1710             1             0  ...                  0
# 1          0       1262             0             1  ...                  0
# 2          1       1786             1             0  ...                  0
# 3          1       1717             1             0  ...                  0
# 4          0       2198             1             0  ...                  0
#
# ...

# %%
ames_raw = pd.read_csv("https://assets.datacamp.com/production/repositories/943/datasets/17a7c5c0acd7bfa253827ea53646cf0db7d39649/ames_unprocessed_data.csv")
ames_raw.head()
# Out:
#    hr  holiday  workingday  temp   hum  windspeed  cnt  instant  mnth  yr  \
# 0   0        0           0  0.76  0.66     0.0000  149    13004     7   1
# 1   1        0           0  0.74  0.70     0.1343   93    13005     7   1
# 2   2        0           0  0.72  0.74     0.0896   90    13006     7   1
# 3   3        0           0  0.72  0.84     0.1343   33    13007     7   1
# 4   4        0           0  0.70  0.79     0.1940    4    13008     7   1
#
#    Clear to partly cloudy  Light Precipitation  Misty
# 0                       1                    0      0
# 1                       1                    0      0
# 2                       1                    0      0
# 3                       1                    0      0
# 4                       1                    0      0

# %%
kidney_disease = pd.read_csv("https://assets.datacamp.com/production/repositories/943/datasets/82c231cd41f92325cf33b78aaa360824e6b599b9/chronic_kidney_disease.csv")
kidney_disease.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...
