# %%
import pandas as pd

stocks_data = pd.read_csv("https://assets.datacamp.com/production/repositories/655/datasets/1304e66b1f9799e1a5eac046ef75cf57bb1dd630/company-stock-movements-2010-2015-incl.csv")
stocks_data.head()
# Out:
#          Unnamed: 0  2010-01-04  2010-01-05  2010-01-06  2010-01-07  \
# 0             Apple    0.580000   -0.220005   -3.409998   -1.170000
# 1               AIG   -0.640002   -0.650000   -0.210001   -0.420000
# 2            Amazon   -2.350006    1.260009   -2.350006   -2.009995
# 3  American express    0.109997    0.000000    0.260002    0.720002
# 4            Boeing    0.459999    1.770000    1.549999    2.690003
#
#    2010-01-08  2010-01-11  2010-01-12  2010-01-13  2010-01-14  ...  \
# 0    1.680011   -2.689994   -1.469994    2.779997   -0.680003  ...
# 1    0.710001   -0.200001   -1.130001    0.069999   -0.119999  ...
# 2    2.960006   -2.309997   -1.640007    1.209999   -1.790001  ...
# 3    0.190003   -0.270001    0.750000    0.300004    0.639999  ...
# 4    0.059997   -1.080002    0.360000    0.549999    0.530002  ...
#
#    2013-10-16  2013-10-17  2013-10-18  2013-10-21  2013-10-22  2013-10-23  \
# 0    0.320008    4.519997    2.899987    9.590019   -6.540016    5.959976
# ...

# %%
eurovision = pd.read_csv("https://assets.datacamp.com/production/repositories/655/datasets/2a1f3ab7bcc76eef1b8e1eb29afbd54c4ebf86f2/eurovision-2016.csv")
eurovision.head()
# Out:
#   From country       To country  Jury A  Jury B  Jury C  Jury D  Jury E  \
# 0      Albania          Belgium      20      16      24      22      24
# 1      Albania   Czech Republic      21      15      25      23      16
# 2      Albania  The Netherlands      22      14      23      24      21
# 3      Albania       Azerbaijan      19      12      11      21      11
# 4      Albania          Hungary       8      13       9      14       9
#
#    Jury Rank  Televote Rank  Jury Points  Televote Points
# 0         25             14          NaN              NaN
# 1         22             22          NaN              NaN
# 2         24             24          NaN              NaN
# 3         13             19          NaN              NaN
# 4         10             10          1.0              1.0

# %%
fish_measurements = pd.read_csv("https://assets.datacamp.com/production/repositories/655/datasets/fee715f8cf2e7aad9308462fea5a26b791eb96c4/fish.csv")
fish_measurements.head()
# Out:
#    Bream  242.0  23.2  25.4  30.0  38.4  13.4
# 0  Bream  290.0  24.0  26.3  31.2  40.0  13.8
# 1  Bream  340.0  23.9  26.5  31.1  39.8  15.1
# 2  Bream  363.0  26.3  29.0  33.5  38.0  13.3
# 3  Bream  430.0  26.5  29.0  34.0  36.6  15.1
# 4  Bream  450.0  26.8  29.7  34.7  39.2  14.2

# %%
grains = pd.read_csv("https://assets.datacamp.com/production/repositories/655/datasets/bb87f0bee2ac131042a01307f7d7e3d4a38d21ec/Grains.zip")
grains.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 grains = pd.read_csv("https://assets.datacamp.com/production/repositories/655/datasets/bb87f0bee2ac131042a01307f7d7e3d4a38d21ec/Grains.zip")
#       2 grains.head()
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
# ...

# %%
lcd = pd.read_csv("https://assets.datacamp.com/production/repositories/655/datasets/effd1557b8146ab6e620a18d50c9ed82df990dce/lcd-digits.csv")
lcd.head()

# %%
music = pd.read_csv("https://assets.datacamp.com/production/repositories/655/datasets/c974f2f2c4834958cbe5d239557fbaf4547dc8a3/Musical%20artists.zip")
music.head()

# %%
wikipedia = pd.read_csv("https://assets.datacamp.com/production/repositories/655/datasets/8e2fbb5b8240c06602336f2148f3c42e317d1fdb/Wikipedia%20articles.zip")
wikipedia.head()

# %%
wine = pd.read_csv("https://assets.datacamp.com/production/repositories/655/datasets/2b27d4c4bdd65801a3b5c09442be3cb0beb9eae0/wine.csv")
wine.head()
