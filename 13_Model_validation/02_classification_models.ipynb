# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
ttt_df = pd.read_csv("https://assets.datacamp.com/production/repositories/3981/datasets/e6ee6604b9eed121a015a993bfb225ddf656cf81/tic-tac-toe.csv")

# %%
ttt_df.head()
# Out:
#   Top-Left Top-Middle Top-Right Middle-Left Middle-Middle Middle-Right  \
# 0        x          x         x           x             o            o
# 1        x          x         x           x             o            o
# 2        x          x         x           x             o            o
# 3        x          x         x           x             o            o
# 4        x          x         x           x             o            o
#
#   Bottom-Left Bottom-Middle Bottom-Right     Class
# 0           x             o            o  positive
# 1           o             x            o  positive
# 2           o             o            x  positive
# 3           o             b            b  positive
# 4           b             o            b  positive

# %%
# first we need to prepare our data for use in a classication model


rfc = RandomForestClassifier(random_state = 1111)
rfc.fit(X_train, y_train)
rfc.predit(X_test)

pd.Series(rfc.predict(X_test)).value_counts()
